# %%
import random
import shutil
import pandas as pd
from icecream import ic
from faker import Faker
from datetime import datetime, timedelta,time
import pendulum
from pathlib import Path
import pyarrow as pa
import os
import pyarrow.csv as csv
import io 
import subprocess
from tabulate import tabulate
import time as tx

# %%
filename1='/home/deck/Documents/inbound/sample.csv'

start_time = tx.perf_counter()
dx = pd.read_csv(f'{filename1}.gz',engine='pyarrow', dtype_backend='pyarrow', delimiter=',', skiprows=0, header=None, encoding='utf-8', compression='gzip')
end_time = tx.perf_counter()
execution_time = end_time - start_time
ic(f"Execution time: {execution_time} seconds")
# Out:
# ic| f"Execution time: {execution_time} seconds": 'Execution time: 5.457265201010159 seconds'
# 'Execution time: 5.457265201010159 seconds'

# %%
dx[50:]
# Out:
#             0         1         2         3         4         5         6   \
# 50          50  0.233270  0.684797  0.627900  0.162999  0.550153  0.147141
# 51          51  0.507490  0.890762  0.918376  0.883839  0.223438  0.701225
# 52          52  0.983975  0.621697  0.997920  0.244941  0.498207  0.555846
# 53          53  0.932471  0.808325  0.722929  0.594528  0.166500  0.133338
# 54          54  0.126733  0.199727  0.623587  0.550455  0.989837  0.330930
# ...        ...       ...       ...       ...       ...       ...       ...
# 999995  999995  0.399978  0.023555  0.820857  0.421595  0.259568  0.538627
# 999996  999996  0.585761  0.329517  0.879897  0.288049  0.221400  0.247725
# 999997  999997  0.145004  0.971210  0.094039  0.828352  0.200312  0.929520
# 999998  999998  0.952995  0.529661  0.442663  0.395972  0.206209  0.066439
# 999999  999999  0.899499  0.692138  0.553069  0.486493  0.956470  0.714213
#
# ...

# %%
dx
# Out:
#             0         1         2         3         4         5         6   \
# 0            0  0.932850  0.697954  0.033668  0.471275  0.088943  0.078763
# 1            1  0.913258  0.682570  0.018733  0.643811  0.738683  0.756411
# 2            2  0.114179  0.329359  0.045073  0.515780  0.599273  0.416165
# 3            3  0.224513  0.224804  0.005370  0.628460  0.929690  0.847794
# 4            4  0.737514  0.746373  0.908565  0.578404  0.793617  0.315350
# ...        ...       ...       ...       ...       ...       ...       ...
# 999995  999995  0.399978  0.023555  0.820857  0.421595  0.259568  0.538627
# 999996  999996  0.585761  0.329517  0.879897  0.288049  0.221400  0.247725
# 999997  999997  0.145004  0.971210  0.094039  0.828352  0.200312  0.929520
# 999998  999998  0.952995  0.529661  0.442663  0.395972  0.206209  0.066439
# 999999  999999  0.899499  0.692138  0.553069  0.486493  0.956470  0.714213
#
# ...

# %%
# !rm -f /home/deck/Documents/inbound/sample.csv.gz

# %%
import csv
import random

# 6666666 and 52 == roughly 1GB (WARNING TAKES a while, 30s+)
rows = 41025637
columns = 66
print_after_rows = 6666666

def generate_random_row(col):
    a = []
    l = [i]
    for j in range(col):
        l.append(random.random())
    a.append(l)
    return a

if __name__ == '__main__':
    f = open('sample.csv', 'w')
    w = csv.writer(f, lineterminator='\n')
    for i in range(rows):
        if i % print_after_rows == 0:
            print(".", end="", flush=True)
        w.writerows(generate_random_row(columns))
    f.close()
# Out:
# .
